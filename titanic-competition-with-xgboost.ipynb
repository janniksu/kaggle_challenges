# %% [markdown]
# <a href="https://www.kaggle.com/code/jannikca/titanic-competition-with-xgboost?scriptVersionId=123744306" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import xgboost as xgb

#Own imports
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spaceship-titanic/sample_submission.csv
# /kaggle/input/spaceship-titanic/train.csv
# /kaggle/input/spaceship-titanic/test.csv

# %% [markdown]
# # **Intention of the Notebook**

# %% [markdown]
# This is my first competition notebook that is independent of any exercise of a course.
# I try to recap lots of concepts on my own to make suitable predictions.
# Later on, I think about how to improve those predictions.

# %%
#Read training and test data
X = pd.read_csv('/kaggle/input/spaceship-titanic/train.csv')
X_test = pd.read_csv('/kaggle/input/spaceship-titanic/test.csv')


#Remove rows with empty target and separate target from predictors
X.dropna(axis=0, subset=['Transported'], inplace=True)
y = X.Transported
X.drop(['Transported'], axis=1, inplace=True)


# Select categorical columns with relatively low cardinality. In fact, we remove columns likes ids or names because they are unique and we cannot learn from them.
categorical_cols = [cname for cname in X.columns if
                    X[cname].nunique() < 20 and 
                    X[cname].dtype == "object"]

# Select numerical columns
numerical_cols = [cname for cname in X.columns if 
                X[cname].dtype in ['int64', 'float64']]


# Keep selected columns only
my_cols = categorical_cols + numerical_cols



X_train = X[my_cols].copy()

# %% [markdown]
# Next, we setup a pipeline to deal with missing values and to encode categorical variables. Afterward, we use an XGBoost model.

# %%
numerical_transformer = SimpleImputer(strategy='mean')

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

model = xgb.XGBClassifier(learning_rate=0.025,n_estimators=500, n_jobs=8)

pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', model)
                     ])

parameters = {
    'model__max_depth': range (2, 5, 1),
    'model__n_estimators': range(60, 250, 20),
    'model__learning_rate': [0.1, 0.01, 0.05]
}


grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=parameters,
    scoring = 'accuracy',
    n_jobs = 4,
    cv = 6,
    verbose=2
)


grid_search.fit(X_train,y)

#scores =  cross_val_score(pipeline, X_train, y,
                           #   cv=5,
                            #  scoring='accuracy')

#Important: Transform predictions into booleans
#predictions = pipeline.predict(X_test).astype('bool')
# Out:
# Fitting 6 folds for each of 90 candidates, totalling 540 fits
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=80; total time=   1.3s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=80; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=120; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=120; total time=   1.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=180; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=220; total time=   3.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=240; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=240; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=80; total time=   1.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   1.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=120; total time=   2.0s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=140; total time=   2.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=160; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=180; total time=   3.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=180; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=220; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=220; total time=   3.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=240; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=80; total time=   1.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=100; total time=   2.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=100; total time=   2.1s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=120; total time=   2.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=140; total time=   3.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=140; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=160; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=180; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=180; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=200; total time=   4.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=220; total time=   4.5s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=220; total time=   4.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=240; total time=   5.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=80; total time=   1.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=80; total time=   1.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=120; total time=   1.7s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=120; total time=   1.5s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=140; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=160; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=180; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   2.8s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=220; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=240; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=240; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   1.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   1.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=120; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=160; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=180; total time=   3.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=180; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=220; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=220; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=240; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=80; total time=   1.8s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=80; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=100; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=120; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=120; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=140; total time=   2.9s[CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=80; total time=   1.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=100; total time=   1.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=120; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=160; total time=   2.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=180; total time=   2.5s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=180; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=220; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=220; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=240; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=80; total time=   1.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=120; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=120; total time=   2.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=160; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=160; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=180; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   3.3s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   3.3s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=220; total time=   3.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=240; total time=   4.0s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=240; total time=   3.9s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=80; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=80; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=100; total time=   2.1s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=120; total time=   2.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=120; total time=   2.5s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=140; total time=   3.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=160; total time=   3.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=160; total time=   3.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=180; total time=   3.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=200; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=200; total time=   4.2s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=220; total time=   4.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=240; total time=   4.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=240; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=60; total time=   0.8s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=80; total time=   1.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=100; total time=   1.3s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=100; total time=   1.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=120; total time=   1.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=140; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=160; total time=   2.3s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=180; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=180; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   2.8s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=220; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=220; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=240; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   1.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   1.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=120; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=160; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=180; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=180; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=220; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=220; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=240; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=60; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=60; total time=   1.5s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=60; total time=   1.5s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=80; total time=   1.9s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=100; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=100; total time=   2.3s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=120; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=140; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=140; total time=   2.9s[CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=80; total time=   1.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=100; total time=   1.5s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=120; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=180; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=180; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=220; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=220; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=240; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=80; total time=   1.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   1.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=120; total time=   2.0s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=120; total time=   2.0s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=140; total time=   2.3s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=160; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=160; total time=   2.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=180; total time=   3.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   3.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=220; total time=   3.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=240; total time=   3.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=240; total time=   3.9s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=60; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=80; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=100; total time=   2.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=100; total time=   2.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=120; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=140; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=140; total time=   2.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=160; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=180; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=180; total time=   3.6s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=200; total time=   4.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=220; total time=   4.6s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=220; total time=   4.5s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=240; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=80; total time=   1.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=80; total time=   1.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=120; total time=   1.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=120; total time=   1.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=140; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=180; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=220; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=240; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=240; total time=   3.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   1.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=120; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=120; total time=   2.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=140; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=160; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=160; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=180; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=220; total time=   3.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=240; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=240; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=80; total time=   1.9s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=80; total time=   1.6s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=100; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=120; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=120; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=140; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=160; total time=   3.2s[CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=60; total time=   0.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=80; total time=   1.3s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=80; total time=   1.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=120; total time=   1.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=120; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=180; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=220; total time=   2.9s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=240; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=240; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=60; total time=   1.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=80; total time=   1.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   1.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   1.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=120; total time=   2.1s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=140; total time=   2.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=140; total time=   2.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=160; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=180; total time=   3.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=180; total time=   2.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=220; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=220; total time=   3.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=240; total time=   3.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=60; total time=   1.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=80; total time=   1.6s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=80; total time=   1.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=100; total time=   2.1s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=120; total time=   2.4s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=120; total time=   2.6s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=140; total time=   2.9s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=160; total time=   3.1s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=160; total time=   3.2s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=180; total time=   3.7s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=200; total time=   3.9s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=200; total time=   4.0s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=220; total time=   4.6s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=240; total time=   4.8s
# [CV] END model__learning_rate=0.1, model__max_depth=4, model__n_estimators=240; total time=   5.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=60; total time=   0.8s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=80; total time=   1.1s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=100; total time=   1.3s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=100; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=120; total time=   1.7s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=140; total time=   1.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=140; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=160; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=180; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=180; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=220; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=220; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=240; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=60; total time=   1.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=80; total time=   1.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   1.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=120; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=120; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=140; total time=   2.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=160; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=160; total time=   2.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=180; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=220; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=240; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=240; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=60; total time=   1.3s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=80; total time=   2.0s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=100; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=100; total time=   2.4s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=120; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=140; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=140; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=4, model__n_estimators=160; total time=   3.4s
# GridSearchCV(cv=6,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(),
#                                                                          ['Age',
#                                                                           'RoomService',
#                                                                           'FoodCourt',
#                                                                           'ShoppingMall',
#                                                                           'Spa',
#                                                                           'VRDeck']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['HomePlanet',
#                                                                           'CryoSleep',
#                                                                           'Destination',
#                                                                           'VI...
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=500,
#                                                       n_jobs=8,
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=None,
#                                                       reg_alpha=None,
#                                                       reg_lambda=None, ...))]),
#              n_jobs=4,
#              param_grid={'model__learning_rate': [0.1, 0.01, 0.05],
#                          'model__max_depth': range(2, 5),
#                          'model__n_estimators': range(60, 250, 20)},
#              scoring='accuracy', verbose=2)

# %%
predictions = grid_search.best_estimator_.predict(X_test)

print(grid_search.best_score_)
# Out:
# 0.7961590326471423

# %%
#print(scores.mean())

# %%
# Run the code to save predictions in the format used for competition scoring
output = pd.DataFrame({'PassengerId': X_test.PassengerId,
                       'Transported': predictions})
output.to_csv('submission.csv', index=False)
